# %%
from inference_pipeline import inpaint_with_bbox_Pipeline
from PIL import Image
import numpy as np

# %%
input_img = Image.open("./skin_head.jpeg")
input_box = np.array([30,15,620,830])
prompt = "anime"

# %%
from inference_pipeline import Img2ImgWithBboxPipeline

# %%
predictor = Img2ImgWithBboxPipeline()
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# /opt/conda/lib/python3.8/site-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
predictor.pipe(input_img,input_box,"anime, masterpiece",strength=1.0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 predictor.pipe(input_img,input_box,"anime, masterpiece",strength=1.0)
#
# File ~/level3_cv_finalproject-cv-16/GPUserver/model/inference_pipeline.py:48, in Img2ImgWithBboxPipeline.pipe(self, image, input_bbox, prompt, inference_steps, strength)
#      46 #2-1. 위에서 추출된 마스크 이외의 배경을 제거한 뒤, 이미지 변환
#      47 segment_img = image_segmentation(image,mask)
# ---> 48 target_image = self.image_translation.inpaint(prompt=prompt,image=segment_img,num_inference_steps=inference_steps,strength=strength)
#      49 #3. 이미지에서 1번에서 추출한 객체를 inpaint를 사용하여 자연스럽게 제거
#      50 # background = self.inpaintor.pipe(image=image,input_bbox=None,prompt="",inference_steps=100,mask=mask)
#      52 background = image
#
# TypeError: inpaint() got an unexpected keyword argument 'strength'

# %%
input_box = np.array([0,400,450,1000]) 
input_img = Image.open("./psp.jpeg")
prompt = "anime"

# %%
sam.make_mask_with_bbox(image=input_img,input_box=input_box)
# Out:
# <PIL.Image.Image image mode=1 size=768x1024>

# %%
predictor.pipe(input_img,input_box,"anime, masterpiece")
# Out:
#   0%|          | 0/60 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=768x1024>

# %%
output = pipe.pipe(input_img,input_box,prompt,inference_steps=150)
output.show()
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F8D733F8910>

# %%
np.array(output).shape
# Out:
# (512, 512, 3)

# %%
from segment_anything_model import SAM

# %%
segmentation = SAM()

# %%
mask = segmentation.make_mask_with_bbox(input_img,input_box)

# %%
np.array(mask).shape
# Out:
# (839, 667)
